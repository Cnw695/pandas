# %%
import pandas as pd
import numpy as np

file = 'students_complete.csv'
students = pd.read_csv(file)
print(students.head())

file2 = 'schools_complete.csv'
schools = pd.read_csv(file2)
print(schools.head())
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
df = pd.merge(students, schools, on='school_name')
#df[df.type == "District"]
df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
totalschools = len(df['school_name'].unique())
totalschools
# Out:
# 15

# %%
totalstudent = df['Student ID'].count()
totalstudent
# Out:
# 39170

# %%
totalbudget = df['budget'].unique().sum()
totalbudget
# Out:
# 24649428

# %%
averagemath = df['math_score'].mean()
averagemath
# Out:
# 78.98537145774827

# %%
averageread = df['reading_score'].mean()
averageread
# Out:
# 81.87784018381414

# %%
#df.dtypes

# %%
#this shouldnt be more than 26976. that is the number of District Students
#district_pass = df['math_score'].mean()
#district_pass

math = df[df['math_score']>=70].count()["student_name"] /  totalstudent
math
#['gender','math_score']]
# Out:
# 0.749808526933878

# %%
reading = df[df['reading_score']>=70].count()["student_name"] /  totalstudent
reading
# Out:
# 0.8580546336482001

# %%
overall = (math + reading) / 2
overall
# Out:
# 0.8039315802910391

# %%
district_summary = pd.DataFrame([{'Total Schools': totalschools, 'Total Students': totalstudent, 'Total Budget': totalbudget,
                       'Average Math': averagemath, 'Average Read': averageread, 'Math Pass %': math, 'Reading Pass %': reading, 'Overall Pass %': overall}
                     ])
district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math  Average Read  \
# 0             15           39170      24649428     78.985371      81.87784
#
#    Math Pass %  Reading Pass %  Overall Pass %
# 0     0.749809        0.858055        0.803932

# %% [markdown]
# # school_summary

# %%
school_names = schools.set_index(['school_name'])['type']
school_names
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
df['math_passing'] = df.loc[df['math_score']>=70, 'math_score']
df['reading_passing'] = df.loc[df['reading_score']>=70, "reading_score"]
df_grouped = df.groupby(['school_name'])
student_count = df_grouped['Student ID'].count()
df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
budget = df_grouped['budget'].mean()
budget.map('${:,.2f}'.format)
# Out:
# school_name
# Bailey High School       $3,124,928.00
# Cabrera High School      $1,081,356.00
# Figueroa High School     $1,884,411.00
# Ford High School         $1,763,916.00
# Griffin High School        $917,500.00
# Hernandez High School    $3,022,020.00
# Holden High School         $248,087.00
# Huang High School        $1,910,635.00
# Johnson High School      $3,094,650.00
# Pena High School           $585,858.00
# Rodriguez High School    $2,547,363.00
# Shelton High School      $1,056,600.00
# Thomas High School       $1,043,130.00
# Wilson High School       $1,319,574.00
# Wright High School       $1,049,400.00
# Name: budget, dtype: object

# %%
budget_perstudent = (budget / student_count)
budget_perstudent
# Out:
# school_name
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
avgmath = df_grouped['math_score'].mean()
avgreading = df_grouped['reading_score'].mean()
avgmath
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
percent_passmath = df_grouped['math_passing'].count() / student_count * 100
percent_passmath
# Out:
# school_name
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
percent_passreading = df_grouped['reading_passing'].count() / student_count * 100
percent_passreading
# Out:
# school_name
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
overallschool = (percent_passreading + percent_passmath) / 2
overallschool.map('{:.2f}%'.format)
# Out:
# school_name
# Bailey High School       74.31%
# Cabrera High School      95.59%
# Figueroa High School     73.36%
# Ford High School         73.80%
# Griffin High School      95.27%
# Hernandez High School    73.81%
# Holden High School       94.38%
# Huang High School        73.50%
# Johnson High School      73.64%
# Pena High School         95.27%
# Rodriguez High School    73.29%
# Shelton High School      94.86%
# Thomas High School       95.29%
# Wilson High School       95.20%
# Wright High School       94.97%
# dtype: object

# %%
school_summary = pd.DataFrame({'School Type': school_names, 'Total Students': student_count,
                               'Total School Budget': budget.map('${:,.2f}'.format), 'Per Student Budget': budget_perstudent,
                              'Average Math Score': avgmath, 'Average Reading Score': avgreading,
                              '% Passing Math': percent_passmath, '% Passing Reading': percent_passreading,
                              'Overall Passing Rate': overallschool})
school_summary
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %%
top_schools = school_summary.sort_values(['Overall Passing Rate'], ascending=False)
top_schools.head()
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Pena High School        Charter             962         $585,858.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Pena High School                  609.0           83.839917
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %% [markdown]
# # bottom performing schools

# %%
top_schools.tail()
# Out:
#                       School Type  Total Students Total School Budget  \
# Ford High School         District            2739       $1,763,916.00
# Johnson High School      District            4761       $3,094,650.00
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Rodriguez High School    District            3999       $2,547,363.00
#
#                        Per Student Budget  Average Math Score  \
# Ford High School                    644.0           77.102592
# Johnson High School                 650.0           77.072464
# Huang High School                   655.0           76.629414
# Figueroa High School                639.0           76.711767
# Rodriguez High School               637.0           76.842711
#
#                        Average Reading Score  % Passing Math  \
# Ford High School                   80.746258       68.309602
# ...

# %%
df.head()
#df_grades = students.groupby(['school_name'])
#student_grades_byschool = df_grades['grade'].unique()
#student_grades_byschool.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget  \
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635
#
#    math_passing  reading_passing
# 0          79.0              NaN
# 1           NaN             94.0
# 2           NaN             90.0
# 3           NaN              NaN
# ...

# %%
grade_group = df.groupby(['school_name', 'grade'])
mathgrade_avg = grade_group['math_score'].mean()
mathgrade_avg

#grade_grouped = students.groupby('school_name')
#grade_grouped[grade_grouped.loc['grade']=='9th'].math_score.mean()
# Out:
# school_name            grade
# Bailey High School     10th     76.996772
#                        11th     77.515588
#                        12th     76.492218
#                        9th      77.083676
# Cabrera High School    10th     83.154506
#                        11th     82.765560
#                        12th     83.277487
#                        9th      83.094697
# Figueroa High School   10th     76.539974
#                        11th     76.884344
#                        12th     77.151369
#                        9th      76.403037
# Ford High School       10th     77.672316
#                        11th     76.918058
#                        12th     76.179963
#                        9th      77.361345
# Griffin High School    10th     84.229064
#                        11th     83.842105
#                        12th     83.356164
#                        9th      82.044010
# Hernandez High School  10th     77.337408
#                        11th     77.136029
# ...

# %%
school_names = schools.set_index(['school_name'])
school_names = df.groupby('grade')
readgrade_avg = grade_group['reading_score'].mean()
readgrade_avg
# Out:
# school_name            grade
# Bailey High School     10th     80.907183
#                        11th     80.945643
#                        12th     80.912451
#                        9th      81.303155
# Cabrera High School    10th     84.253219
#                        11th     83.788382
#                        12th     84.287958
#                        9th      83.676136
# Figueroa High School   10th     81.408912
#                        11th     80.640339
#                        12th     81.384863
#                        9th      81.198598
# Ford High School       10th     81.262712
#                        11th     80.403642
#                        12th     80.662338
#                        9th      80.632653
# Griffin High School    10th     83.706897
#                        11th     84.288089
#                        12th     84.013699
#                        9th      83.369193
# Hernandez High School  10th     80.660147
#                        11th     81.396140
# ...

# %%
spending_bins = [0, 585, 615, 645, 675]
group_names = ["< $585", "$585-615", "$615-645", "$645-675"]

school_summary['Spending Ranges (Per Student)'] = pd.cut(school_summary['Per Student Budget'], spending_bins, labels=group_names)

school_bin = school_summary.groupby('Spending Ranges (Per Student)') 
print(school_bin['Spending Ranges (Per Student)'].count())

school_bin[['Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading',
           'Overall Passing Rate']].mean()

#school_spending = school_summary['Spending Ranges (Per Student)'].unique()


#school_spend = school_summary.set_index(['Spending Ranges (Per Student)'])

#school_spend.head()



#school_spend = pd.DataFrame(index=([group_names], [school_spending]), 
#columns=(['Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading', 'Overall Passing Rate']))
# Out:
# Spending Ranges (Per Student)
# < $585      4
# $585-615    2
# $615-645    6
# $645-675    3
# Name: Spending Ranges (Per Student), dtype: int64
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# < $585                                  83.455399              83.933814
# $585-615                                83.599686              83.885211
# $615-645                                79.079225              81.891436
# $645-675                                76.997210              81.027843
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# < $585                              93.460096          96.610877
# $585-615                            94.230858          95.900287
# $615-645                            75.668212          86.106569
# $645-675                            66.164813          81.133951
#
#                                Overall Passing Rate
# ...

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_name = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

school_summary['School Size'] = pd.cut(school_summary['Total Students'], size_bins, labels=group_name)
school_vol = school_summary.groupby('School Size')
print(school_vol['School Size'].count())
school_vol[['Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading',
            'Overall Passing Rate']].mean()
# Out:
# School Size
# Small (<1000)         2
# Medium (1000-2000)    5
# Large (2000-5000)     8
# Name: School Size, dtype: int64
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  Overall Passing Rate
# School Size
# Small (<1000)               96.099437             94.824831
# Medium (1000-2000)          96.790680             95.195187
# Large (2000-5000)           82.766634             76.364998

# %%
#school_names = schools.set_index(['type']).count()
#school_summary['School Type'] = pd.cut(school_summary[])
school_type = school_summary.groupby('School Type')
print(school_type['School Type'].count())
school_type[['Average Math Score', 'Average Reading Score', '% Passing Math', '% Passing Reading',
            'Overall Passing Rate']].mean()
# Out:
# School Type
# Charter     8
# District    7
# Name: School Type, dtype: int64
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  Overall Passing Rate
# School Type
# Charter              96.586489             95.103660
# District             80.799062             73.673757
